# %%
# import flask dependencies
from flask import Flask, request, make_response, jsonify
import requests
from requests.auth import HTTPBasicAuth
import json


# initialize the flask app
app = Flask(__name__)

# default route
@app.route('/')
def index():
    return 'Hello World!'

# function for responses
def results():
    # build a request object
    req = request.get_json(force=True)
    
    
    if req['queryResult']['intent']['displayName'] == 'english - book appointment - banaguluru':
        search_id = req['queryResult']['parameters']['Banguluruhospitals']
        api_response = requests.get('https://test.manipalhospitals.com/chatbot-get-hospitals-speciality/'+str(search_id),auth = HTTPBasicAuth('manipalchatbotapi','manipalchatbotapi'))
        speciality_response = json.loads(api_response.text)
        items = []
        for i in range(len(speciality_response)):
            my_dict = {}
            my_dict["info"] = {"key":speciality_response[i]['name']}
            my_dict["title"] = speciality_response[i]['name']
            my_dict["image"] = {}
            items.append(my_dict)
        return {
        "fulfillmentMessages": [
          {
            "platform": "ACTIONS_ON_GOOGLE",
            "simpleResponses": {
              "simpleResponses": [
                {
                  "textToSpeech": "Select the specialty you are looking for:"
                }
              ]
            }
          },
          {
            "platform": "ACTIONS_ON_GOOGLE",
            "listSelect": {
              "title": "Centre Of Excellence",
              "items": items
            }
          }
        ]}
    
    if req['queryResult']['intent']['displayName'] == 'english - book appointment - otherhospitals':
        search_id = req['queryResult']['parameters']['otherhospitals']
        api_response = requests.get('https://test.manipalhospitals.com/chatbot-get-hospitals-speciality/'+str(search_id),auth = HTTPBasicAuth('manipalchatbotapi','manipalchatbotapi'))
        speciality_response = json.loads(api_response.text)
        items = []
        for i in range(len(speciality_response)):
            my_dict = {}
            my_dict["info"] = {"key":speciality_response[i]['name']}
            my_dict["title"] = speciality_response[i]['name']
            my_dict["image"] = {}
            items.append(my_dict)
        return {
        "fulfillmentMessages": [
          {
            "platform": "ACTIONS_ON_GOOGLE",
            "simpleResponses": {
              "simpleResponses": [
                {
                  "textToSpeech": "Select the specialty you are looking for:"
                }
              ]
            }
          },
          {
            "platform": "ACTIONS_ON_GOOGLE",
            "listSelect": {
              "title": "Centre Of Excellence",
              "items": items
            }
          }
      ]}
    
    #print(req)
    if req['queryResult']['intent']['displayName'] == 'english - find doctors - specialties1' or 'old airport road - cardiology':
        #loc_id= req['queryResult']['parameters']['Banguluruhospitals']['otherhospitals']
        
        search_id = req['queryResult']['parameters']['Specialties']
        api_response = requests.get('https://test.manipalhospitals.com/chatbot-get-doctor-by-speciality/'+req['queryResult']['outputContexts'][0]['parameters']['Banguluruhospitals']+'/'+str(search_id),auth = HTTPBasicAuth('manipalchatbotapi','manipalchatbotapi'))
#         api_response = requests.get('https://www.manipalhospitals.com/patient_api/index_get',auth = HTTPBasicAuth('manipal','M@AnipalDoc##2020'))
        api_response = json.loads(api_response.text)
        items = []
        for i in range(10):
            my_dict = {}
            image_dict = {}
            key = {}
            key['key'] = api_response[i]['DoctorCode']
            image_dict['imageUri'] = api_response[i]['photo']
            image_dict['accessibilityText'] = api_response[i]['doc_name']
            my_dict['info'] = key
            my_dict['title'] = api_response[i]['doc_name']
            my_dict['description'] = api_response[i]['DeptName']
            my_dict['image'] = image_dict
            items.append(my_dict)
        
        return  {'fulfillmentMessages': [
      {
        "platform": "ACTIONS_ON_GOOGLE",
        "simpleResponses": {
          "simpleResponses": [
            {
              "textToSpeech": "Here is the list of Doctors"
            }
          ]
        }
      },
       {
         "platform": "ACTIONS_ON_GOOGLE",
         "carouselSelect": {
           "items":items
         }
       }
     ]}
    
    
    # fetch action from json
    
    #return {'fulfillmentMessages':[{"text":{"text":['Hello']}}]}
    # return a fulfillment response
    

# create a route for webhook
@app.route('/webhook/', methods=['GET', 'POST'])
def webhook():
    # return response
    return make_response(jsonify(results()))

# run the app
if __name__ == '__main__':
   app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [19/Nov/2020 13:22:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Nov/2020 13:22:56] "GET /favicon.ico HTTP/1.1" 404 -

# %%
req = {'responseId': '5d2cd7c9-1f78-4f0e-a926-9e5deb3b125b-5d846bd5', 'queryResult': {'queryText': 'cardiology', 'action': 'DefaultWelcomeIntent.DefaultWelcomeIntent-custom.english-custom.english-finddoctors-custom', 'parameters': {}, 'allRequiredParamsPresent': True, 'fulfillmentMessages': [{'platform': 'ACTIONS_ON_GOOGLE', 'simpleResponses': {'simpleResponses': [{'textToSpeech': 'Below are the concern doctor for you.'}]}}, {'platform': 'ACTIONS_ON_GOOGLE', 'simpleResponses': {'simpleResponses': [{'textToSpeech': 'Click on card for book appointment and View detail.'}]}}, {'platform': 'ACTIONS_ON_GOOGLE', 'carouselSelect': {'items': [{'info': {'key': 'DR. ANAND R SHENOY'}, 'title': 'DR. ANAND R SHENOY', 'description': 'Consultant - Interventional Cardiology', 'image': {'imageUri': 'https://www.manipalhospitals.com/uploads/doctors_photo/Cardiology_-_Dr_Anand_Shenoy4.png', 'accessibilityText': 'DR. ANAND R SHENOY'}}, {'info': {'key': 'DR. CHAKRAPANI B S'}, 'title': 'DR. CHAKRAPANI B S', 'description': 'Consultant - Cardiology', 'image': {'imageUri': 'https://www.manipalhospitals.com/uploads/doctors_photo/Cardiology_-_Dr_Chakrapani_B_S.png', 'accessibilityText': 'DR. CHAKRAPANI B S'}}, {'info': {'key': 'DR. BIPIN KUMAR DUBEY'}, 'title': 'DR. BIPIN KUMAR DUBEY', 'description': 'HOD And Consultant - Cardiac Science', 'image': {'imageUri': 'https://www.manipalhospitals.com/uploads/doctors_photo/Dr_Bipin_Dubey.png', 'accessibilityText': 'DR. BIPIN KUMAR DUBEY'}}]}}, {'text': {'text': ['']}}], 'outputContexts': [{'name': 'projects/manipal-chatbot-test-ceks/locations/global/agent/sessions/3a0c4b99-46d3-03cc-7246-4eb13124b3da/contexts/english-finddoctors-followup', 'lifespanCount': 1}, {'name': 'projects/manipal-chatbot-test-ceks/locations/global/agent/sessions/3a0c4b99-46d3-03cc-7246-4eb13124b3da/contexts/english-followup', 'parameters': {'language': ['English'], 'language.original': ['english']}}, {'name': 'projects/manipal-chatbot-test-ceks/locations/global/agent/sessions/3a0c4b99-46d3-03cc-7246-4eb13124b3da/contexts/__system_counters__', 'parameters': {'no-input': 0.0, 'no-match': 0.0}}], 'intent': {'name': 'projects/manipal-chatbot-test-ceks/agent/intents/c1bbc7b5-d76c-40d4-ad37-6ade463ef46e', 'displayName': 'english - find doctors - specialties1'}, 'intentDetectionConfidence': 1.0, 'languageCode': 'en'}, 'originalDetectIntentRequest': {'source': 'DIALOGFLOW_CONSOLE', 'payload': {}}, 'session': 'projects/manipal-chatbot-test-ceks/locations/global/agent/sessions/3a0c4b99-46d3-03cc-7246-4eb13124b3da'}

# %%
req['queryResult']['intent']['displayName']

# %%
import requests
from requests.auth import HTTPBasicAuth

api_response = requests.get('https://test.manipalhospitals.com/chatbot-get-doctor-by-speciality/1/3',auth = HTTPBasicAuth('manipalchatbotapi','manipalchatbotapi'))
#         api_response = requests.get('htt
api_response
# Out:
# <Response [200]>

# %%
import json
api_response = json.loads(api_response.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-0853a5624ee7> in <module>
#       1 import json
# ----> 2 api_response = json.loads(api_response.text)
#
# AttributeError: 'list' object has no attribute 'text'

# %%
import pygsheets
#authorization
gc = pygsheets.authorize(service_file='muliplier-bot-iyl9-ccd96b75d437.json')


#open the google spreadsheet (where 'PY to Gsheet Test' is the name of my sheet)
sh = gc.open('multiplier_bot_data')
wks = sh[0]
old_df = wks.get_as_df()
#select the first sheet 

# new_df = pd.concat([old_df,df])
# #update the first sheet with df, starting at cell B2. 
# wks.set_dataframe(new_df,(1,1))

# %%
old_df.head()
# Out:
# Empty DataFrame
# Columns: [User ID, Mobile_Number, User_message, Bot_message, Timestamp, Session id]
# Index: []

# %%
import requests
from requests.auth import HTTPBasicAuth

api_response = requests.get('https://test.manipalhospitals.com/chatbot-get-hospitals-speciality/2',auth = HTTPBasicAuth('manipalchatbotapi','manipalchatbotapi'))

# %%
api_response
# Out:
# <Response [200]>

# %%
import json
api_response = json.loads(api_response.text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-5-0853a5624ee7> in <module>
#       1 import json
# ----> 2 api_response = json.loads(api_response.text)
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 5 (char 4)

# %%
api_response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0030902b59ff> in <module>
# ----> 1 api_response
#
# NameError: name 'api_response' is not defined

# %%
import requests

from requests.auth import HTTPBasicAuth

api_response = requests.get('https://test.manipalhospitals.com/chatbot-get-doctor-by-speciality/1/3',auth = HTTPBasicAuth('manipalchatbotapi','manipalchatbotapi'))

# %%
api_response
# Out:
# <Response [200]>

# %%
import json
doc_response = json.loads(api_response.text)

# %%
doc_response
# Out:
# [{'doctor_id': '3',
#   'DoctorCode': 'MHBCARD3',
#   'DeptCode': 'MHBDCAR',
#   'DeptName': 'CARDIOLOGY MHB',
#   'doctors_codes.designation': 'Consultant - Interventional Cardiology',
#   'title_text': '',
#   'doctors.qualification': 'MBBS\nMD\nDM\nFICC\nFSCAI\nMEAPCI\nFESC\nFACC\nFRCP (ED)',
#   'profile': None,
#   'photo': 'https://www.manipalhospitals.com/uploads/doctors_photo/Cardiology_-_Dr_Anand_Shenoy4.png',
#   'content': '',
#   'doctors.fellowship_membership': 'FSCAI- Fellow of Society of Cardiovascular Angiography and Interventions (USA)\nFICC – Fellow of Indian College of Cardiology (INDIA)\nMember of European Association of Percutaneous Coronary Interventions (MEAPCI). FESC (Fellow of European Society of Cardiology)',
#   'doctors.field_expertise': 'Ischemic Heart Disease. CAD, Angioplasty (PTCA)\nPrimary PCI\nPeripheral Interventional Pacemakers\nDevice Closure',
#   'doctors.languages_spoken': 'Kannada \nHindi\nEnglish\nKonkani',
#   'doctors.awards_achievements': 'Trained in LMCA Intervention at ASAN Medical Centre Seoul, S. Korea\nTrained in CTO and Retrograde Technique at Kamakura and Yokohamas, Japan under Dr. Shigeru Saito and Dr. Muramatso\nCochrane Research Scholarship Award (2010)',
#   'doctors.talks_publications': "Non-surgical Septal Reduction for Hypertrophic Cardiomyopathy in childhood, V. Subash Chandra, M. Jayranganth and Anand R. Shenoy, Department of Cardiology, Manipal Heart Foundation, Bangalore 560 017, India, International Journal of Cardiology 106(2006) 355 – 359.\n\nPerimembranous VSD closure using Duct Occluder, M Jayranganath, Anand Shenoy, Padmakumar, V Subashchandra, Department of Cardiology, Manipal Heart Foundation, Bangalore 560 017, India. Paper presented at the Fourth World Congress of Paediatric Cardiology & Cardiac Surgery held on September 18-22, 2005 in Buenos Aires, Argentina \n\nPTSMA in childhood – A Case Report & Percutaneous RSOV closure using Duct Occluder – A Case Report – Department of Cardiology, Manipal Heart Foundation, Bangalore 560 017, India. Posters presented at IJN 1st live course in Paediatric Cardiology held at Kuala Lumpur, Malaysia in March 2004.\n\nTranscatheter closure of aortopulmonary window using Amplatzer device, Naik GD, Chandra VS, Shenoy A, Isaac BC, Shetty GG, Padmakumar P, Jayranganath M. St. John's Medical College Hospital, Bangalore, India. Catheter Cardiovasc Interv. 2003 Jul; 59(3):4025. \n\nAcquired aortopulmonary fistula, Shenoy AR, Naik GD, Varghese K, Shetty GG, Iyengar SS, St. John's Medical College Hospital, Bangalore, India. Indian Heart J. 2003 May-Jun; 55(3):268-71. \n\nPremature Coronary Artery Disease, AR Shenoy, BK Raghunandan, BC Isaac, K Varghese, SS Iyengar, St John’s Medical College Hospital, Bangalore, Indian Heart J. 2003 Sept-Oct; 55(5) Abstract Issue. \n\nRelative Left Ventricular Wall Thickness in Dilated Cardiomyopathy, AR Shenoy, K Varghese, SS Iyengar, St John’s Medical College Hospital, Bangalore, Indian Heart J. 2003 Sept-Oct; 55(5) Abstract Issue. \n\nLeft Atrial Size and Volume in Coronary Artery Disease and Non coronary Artery Disease Patients Compared to Normal Persons, AR Shenoy, K Varghese, SS Iyengar, St John’s Medical College Hospital, Bangalore, Indian Heart J. 2003 Sept-Oct; 55(5) Abstract Issue. \n\nA Study of Prevalence of Metabolic Syndrome in Patients with Ischemic Heart Disease in South India, FR Nadri, B Isaac, AR Shenoy, K Varghese, SS Iyengar, St John’s Medical College Hospital, Bangalore, Indian Heart J. 2003 Sept-Oct; 55(5) Abstract Issue. \n\nLeft Atrial Size and Volume in Correlation With Left Ventricular Mass, Diastolic Dysfunction and Cardiovascular Risk Burden, AR Shenoy, K Varghese, SS Iyengar, St John’s Medical College Hospital, Bangalore, Indian Heart J. 2003 Sept-Oct; 55(5) Abstract Issue \n\nGross left ventricular voltage with preexcitation in isolated left ventricular non-compaction, Shenoy AR, Naik GD, Varghese K, Shetty GG, Iyengar SS, St. John's Medical College Hospital, Bangalore, J Association Physicians India. 2003 Oct; 51:1017-20.",
#   'doctors.meta_title': 'Dr Anand R Shenoy | Consultant Interventional Cardiologist in Oldairportroad, Bangalore',
#   'doctors.meta_description': 'Dr. Anand R Shenoy is a consultant interventional cardiologist in Oldairportroad, Bangalore works at Manipal Hospitals expertise in heart disease treatment. Book Appointment Online.',
#   'doctors.meta_keywords': '',
#   'other_meta_tags': '',
#   'display_order': '1',
#   'slug': 'dr-anand-r-shenoy-consultant-interventional-cardiology',
#   'status_ind': '1',
#   'created_date': '2019-12-17 21:22:06',
#   'last_modified_date': '2020-06-12 04:37:53',
#   'created_by': '1',
#   'last_modified_by': '3',
#   'doc_name': 'Dr. Anand R Shenoy'},
#  {'doctor_id': '12',
#   'DoctorCode': 'MHBDC1976',
#   'DeptCode': 'MHBDCAR',
#   'DeptName': 'CARDIOLOGY MHB',
#   'doctors_codes.designation': 'Consultant - Cardiology',
#   'title_text': '',
#   'doctors.qualification': 'B.Sc - Mysore University\nMBBS - Mysore University \nDNB (Internal Medicine)\nNBE - New Delhi Senior Residency in Cardiology, Nizam Institute of Cardiology\nDM (Cardiology)\nMNAMS LTMMC & LTMGH, Sion, Mumbai, Mumbai University\nFCSI Cardiological Society of India',
#   'profile': None,
#   'photo': 'https://www.manipalhospitals.com/uploads/doctors_photo/Cardiology_-_Dr_Chakrapani_B_S.png',
#   'content': '',
#   'doctors.fellowship_membership': 'Life member of Cardiological Society of India\nLife members of Association of Physicians of India\nLife member of Indian Medical Association\nMember of National Academy of Medical Sciences, New Delhi',
#   'doctors.field_expertise': 'Interventional Cardiology\nInvasive and Non-invasive Cardiology\nPerformed more than 6000 invasive cardiac procedures\nFirst group to start era of Primary Angioplasty for Acute Myocardial Infarction India\nSpecialized in Cardiology from leading, very high volume Institute in Mumbai for Coronary Artery Disease and Intervention - LTMMC & LTMGH, SION, Mumbai and Similar high volume Institute in Hyderabad- NIZAMS Institute of Cardiology\nExperience in Nuclear Cardiology from TATA Memorial Hospital, Parle, Mumbai',
#   'doctors.languages_spoken': 'Kannada\nEnglish\nHindi\nTamil\nTelugu',
#   'doctors.awards_achievements': 'Successfully managed “ICCU on Wheels” project in 2000 the first of its kind in Karnataka, with state of the art facility like Pre- hospital thrombolysis, temporary pacemaker and ventilator, pulse oxymeter, tele electro cardiology, which is a is joint venture of Manipal Hospital, Tumkur & Manipal Heart Foundation, Bangalore & Rotary Midtown, Bangalore aiming at providing sophisticated, evidence based cost effective Acute Cardiac Care for semi-urban and rural population at their door step. Presently introduced in USA as H2H care.\nThis facility takes care of patients in total- starting with transporting AMI patient’s from their home – (H2H) to hospital and managing in ICCU, risk stratification and accordingly taking them to MHF for performing Coronary Angiographies & Angioplasty and other required invasive procedures.\nProject on Acute Cardiac Emergency Transfer set up is feasible and enormously beneficial to the patients and to the public at large with mortality of 1%.',
#   'doctors.talks_publications': '',
#   'doctors.meta_title': 'Dr Chakrapani B S | Senior Consultant Cardiologist in Oldairportroad, Bangalore',
#   'doctors.meta_description': 'Dr Chakrapani B S is a senior consultant cardiologist in Oldairportroad, Bangalore Works at Manipal Hospitals expertise in interventional cardiology. Book Appointment Online.',
#   'doctors.meta_keywords': '',
#   'other_meta_tags': '',
#   'display_order': '1',
#   'slug': 'dr-chakrapani-b-s-senior-consultant-cardiology',
#   'status_ind': '1',
#   'created_date': '2019-12-17 21:15:03',
#   'last_modified_date': '2020-06-17 05:35:28',
#   'created_by': '1',
#   'last_modified_by': '3',
#   'doc_name': 'Dr. Chakrapani B S'},
#  {'doctor_id': '4',
#   'DoctorCode': 'MHBDC9829',
#   'DeptCode': 'MHBDPCS',
#   'DeptName': 'PAEDIATRIC CARDIOLOGY  MHB',
#   'doctors_codes.designation': 'Consultant - Paediatric Cardiology',
#   'title_text': '',
#   'doctors.qualification': 'MBBS (JSS Medical College, Mysore)\nMD (Paediatrics) (JSS Medical College, Mysore)\nDNB (Paediatric Cardiology) (Narayana Hrudayalaya, Bangalore)',
#   'profile': None,
#   'photo': 'https://www.manipalhospitals.com/uploads/doctors_photo/Caridology_-_Dr_Kavya_Mallikarjun.png',
#   'content': '',
#   'doctors.fellowship_membership': 'Member of Indian Academy of Paediatrics\nMember of PCSI.\nIndian Medical Association\nLife member of Cardiological Society of India\nLife member of Indian Academy of Echocardiography',
#   'doctors.field_expertise': 'Clinical Paediatric Cardiology\nEchocardiography(TTE & TEE)\nInvasive Paediatric Cardiology (Diagnostic Cardiac Catheterization, Device Closure of ASD ,PDA & VSD, Valvuloplasty & Coarctoplasty)\nFetal Echocardiography & Counselling\nPost-operative care of Paediatric Cardiac Surgical Patients',
#   'doctors.languages_spoken': 'Kannada\nHindi\nEnglish',
#   'doctors.awards_achievements': '',
#   'doctors.talks_publications': 'Publications in National & International Journals',
#   'doctors.meta_title': 'Dr. Kavya Mallikarjun | Best Pediatrician in Whitefield Bangalore-Manipal Hospitals',
#   'doctors.meta_description': 'Dr. Kavya Mallikarjun is a Best Pediatrician in Manipal Hospitals Whitefield, Bangalore. She has expertise in areas like Clinical Pediatric Cardiology, Echocardiography-Book Appointments',
#   'doctors.meta_keywords': '',
#   'other_meta_tags': '',
#   'display_order': '1',
#   'slug': 'dr-kavya-mallikarjun-consultant-paediatric-cardiology',
#   'status_ind': '1',
#   'created_date': '2020-06-04 08:22:42',
#   'last_modified_date': '2020-07-01 21:50:09',
#   'created_by': '1',
#   'last_modified_by': '3',
#   'doc_name': 'Dr. Kavya Mallikarjun'},
#  {'doctor_id': '16',
#   'DoctorCode': 'MHBCARD5',
#   'DeptCode': 'MHBDCAR',
#   'DeptName': 'CARDIOLOGY MHB',
#   'doctors_codes.designation': 'Consultant - Cardiology',
#   'title_text': '',
#   'doctors.qualification': 'MBBS\nMD\nDTCD\nFRACP\nFICC',
#   'profile': None,
#   'photo': 'https://www.manipalhospitals.com/uploads/doctors_photo/Cardiology_-_Dr_KSS_Bhat.png',
#   'content': '',
#   'doctors.fellowship_membership': 'Honoured by Cardiology Society of Indian, Karnataka and Bangalore Chapter\nHonoured by Association of Paediatrician of India, Karnataka Chapter\nConducted the Bangalore Heart Project (1989) in Manipal Hospital\nConducted for the first time a week long programme on Preventive Cardiology for Physicians and public in 1991',
#   'doctors.field_expertise': 'Ischemic Heart Disease\nClinical Cardiology\nPreventive Cardiology\nHypertension and Heart Failure',
#   'doctors.languages_spoken': 'Kannada\nTulu\nHindi\nEnglish',
#   'doctors.awards_achievements': 'Honoured by Cardiology Society of Indian, Karnataka and Bangalore Chapter\nHonoured by Association of Paediatrician of India, Karnataka Chapter\nConducted the Bangalore Heart Project (1989) in Manipal Hospital\nConducted for the first time a week long programme on Preventive Cardiology for Physicians and public in 1991',
#   'doctors.talks_publications': '',
#   'doctors.meta_title': 'Dr K S S Bhat | Consultant Interventional Cardiologist in Oldairportroad, Bangalore',
#   'doctors.meta_description': 'Dr K S S Bhat is a consultant interventional cardiology in Oldairportroad, Bangalore Works at Manipal Hospitals expertise in ischemic heart disease. Book Appointment Online.',
#   'doctors.meta_keywords': '',
#   'other_meta_tags': '',
#   'display_order': '1',
#   'slug': 'dr-k-s-s-bhat-consultant-interventional-cardiology',
#   'status_ind': '1',
#   'created_date': '2019-12-17 21:15:03',
#   'last_modified_date': '2020-06-10 18:48:09',
#   'created_by': '1',
#   'last_modified_by': '3',
#   'doc_name': 'Dr. KSS Bhat'},
#  {'doctor_id': '18',
#   'DoctorCode': 'MHBDC1799',
#   'DeptCode': 'MHBDPCS',
#   'DeptName': 'PAEDIATRIC CARDIOLOGY  MHB',
#   'doctors_codes.designation': 'Consultant - Paediatric Cardiology',
#   'title_text': '',
#   'doctors.qualification': 'MBBS - Medical College, Calcutta, 1998 \nMD (Paediatrics), SCB Medical College, Cuttack 2003\nPost-Doctoral Fellowship in Paediatric Cardiology, National Board of Examinations, Escorts Heart Institute & Research Centre, New Delhi',
#   'profile': None,
#   'photo': 'https://www.manipalhospitals.com/uploads/doctors_photo/Cardiology_-_Dr_Maitri_Chaudhuri.png',
#   'content': '',
#   'doctors.fellowship_membership': 'Paediatric Cardiac Society of India\nIndian Academy of Echocardiography\nCardiology Society of India-Karnataka Chapter\nBangalore Paediatric Society',
#   'doctors.field_expertise': 'Fetal and Transitional Hemodynamic Evaluation in precious pregnancies\nNeonatal Cardiology and handling of life threatening Cardiac Emergencies\nStructural Heart Disease and its treatment by surgical and non -surgical modalities\nAcquired heart diseases in children including Kawasaki Disease, Paediatric Syncope, Paediatric Hypertension and Paediatric Arrhythmias\nGrown up Congenital Heart Disease – 15 years follow up, treatment, imaging and data recording\nCommunity outreach OPD in paediatric cardiology in remote North East India – a philanthropic project\nReviewer in Journal of Indian Academy of Echocardiography',
#   'doctors.languages_spoken': 'English\nHindi\nBengali\nOriya\nKannada',
#   'doctors.awards_achievements': 'Natesha Pandian award for best Echocardiography Imaging in annual conference of Indian Academy of Echocardiography 2013\nSavitri Shrivastav award on best imaging modality in annual conference of Paediatric Cardiac Society of India 2017\nFirst prize in post graduate neonatology quiz of National Neonatology Forum in East Zone in 2002\nExpert module preparation in Kawasaki Disease for Indian Academy of Paediatrics\nPublications in National and International journals and text books.\nTraining of trainers for functional Echocardiography in Neonatal ICU\nConducted Echo course for GE engineers.\nConducted Advanced Fetal and 3dimensional echo workshop for cardiologists at Manipal Hospital, Bangalore 2017\n',
#   'doctors.talks_publications': 'Dilated superior vena cava in Fetal echocardiographic three -vessel view: what lies ahead? Chaudhuri M, et al. Heart Asia.2018\nGiant ductal pseudoaneurysm in infancy: a lesson learnt the hard way. Chaudhuri M, et al.\nBMJ Case Rep.2017\nHypertension, Stroke and Abdominal Bruit: A Cryotic Extracranial Moyamoya! Chaudhuri M, et al. Indian J Paediatrics.2016\nCatastrophic presentation of anomalous origin of right pulmonary artery in a neonate- an interesting differential! Chaudhuri M, et al. Paediatric Cardiology 2012\nPercutaneous recanalization of an occluded hepatic vein in a difficult subset of paediatric Budd -Chiari syndrome. Chaudhuri M, et al. Paediatric Cardiology 2012\nPercutaneous device closure of a bifurcated inferior vena cava and completion of the Kawashima procedure for the “difficult” univentricular heart. Chaudhuri m, et al. Paediatric Cardiology 2011\nDuctal aneurysm masquerading as non- resolving pneumonia: A challenging differential! Chaudhuri M, et al. Annals of Paediatric Cardiology 2010\nVascular rings and slings in textbook of paediatric cardiology 1st edition. Editor IB Vijalayalaxmi. Publisher Jaypee Brothers\nSingle Ventricle in textbook of paediatric cardiology 1st edition. Editor IB Vijalayalaxmi\nParental awareness website on Paediatric Cardiology: www.babyheart.in from 2010',
#   'doctors.meta_title': 'Dr Maitri Chaudhuri | Consultant Pediatric Cardiologist in Oldairportroad, Bangalore',
#   'doctors.meta_description': 'Dr Maitri Chaudhuri is a consultant pediatric cardiologist in Oldairportroad, Bangalore Works at Manipal Hospitals expertise in neonatal cardiology. Book Appointment Online.',
#   'doctors.meta_keywords': '',
#   'other_meta_tags': '',
#   'display_order': '1',
#   'slug': 'dr-maitri-chaudhuri-consultant-pediatric-cardiology',
#   'status_ind': '1',
#   'created_date': '2020-06-04 08:22:42',
#   'last_modified_date': '2020-06-11 04:31:45',
#   'created_by': '1',
#   'last_modified_by': '3',
#   'doc_name': 'Dr. Maitri Chaudhuri'},
#  {'doctor_id': '21',
#   'DoctorCode': 'MHBDC1796',
#   'DeptCode': 'MHBDCAR',
#   'DeptName': 'CARDIOLOGY MHB',
#   'doctors_codes.designation': 'Consultant - Interventional Cardiology',
#   'title_text': '',
#   'doctors.qualification': 'MBBS : Stanley Medical College and Hospital, Madras\nMD (General Medicine) : Madras Medical College & Government General Hospital, Madras \nDM (Cardiology) : Christian Medical College and Hospital',
#   'profile': None,
#   'photo': 'https://www.manipalhospitals.com/uploads/doctors_photo/Cardiology_-_Dr_Padma_Kumar.png',
#   'content': '',
#   'doctors.fellowship_membership': 'Cardiological Society of India',
#   'doctors.field_expertise': 'Paediatric and Adult Interventional Cardiology\nComplex Coronary Interventions\nComplex Paediatric Interventions\nPeripheral Interventions',
#   'doctors.languages_spoken': 'Kannada\nHindi\nEnglish\nMalayalam\nTamil',
#   'doctors.awards_achievements': 'Have been involved actively in Paediatric and Adult Coronary and Non Coronary Intervention in Structural Heart Diseases for over two decades\nBest outgoing student in MBBS and MD in the University of Kerala',
#   'doctors.talks_publications': '',
#   'doctors.meta_title': 'Dr Padmakumar P | Consultant Interventional Cardiologist in Oldairportroad, Bangalore',
#   'doctors.meta_description': 'Dr Padmakumar P is a consultant interventional cardiologist in Oldairportroad, Bangalore Works at Manipal Hospitals expertise in coronary interventions. Book Appointment Online.',
#   'doctors.meta_keywords': '',
#   'other_meta_tags': '',
#   'display_order': '1',
#   'slug': 'dr-padmakumar-p-2-consultant-interventional-cardiology',
#   'status_ind': '1',
#   'created_date': '2019-12-16 07:07:21',
#   'last_modified_date': '2020-06-12 05:39:23',
#   'created_by': '1',
#   'last_modified_by': '3',
#   'doc_name': 'Dr. Padmakumar P'},
#  {'doctor_id': '11',
#   'DoctorCode': 'MHBDC9775',
#   'DeptCode': 'MHBDCAR',
#   'DeptName': 'CARDIOLOGY MHB',
#   'doctors_codes.designation': 'HOD & Consultant - Interventional Cardiology',
#   'title_text': '',
#   'doctors.qualification': 'MD (AIIMS)\nDM (PGIMER)\nFACC\nFESC\nFSCAI\nMBA',
#   'profile': None,
#   'photo': 'https://www.manipalhospitals.com/uploads/doctors_photo/Cardiology_-_Dr_Ranjan_Shetty.png',
#   'content': '',
#   'doctors.fellowship_membership': 'Member of American College of Cardiology\nMember of European Society of Cardiology\nMember of Society for Cardiovascular Angiography and Intervention\nMember of Cardiology Society of India',
#   'doctors.field_expertise': 'Pioneer in Left Atrial Appendage device closure in South East Asia\nExpertise in Trans-Aortic Valve Implantations\nExpertise in complex coronary interventions especially chronic total occlusion, left main interventions, rota-ablation, bifurcation lesions\nExpertise in Device Implantations especially para-valvular leak closures, atrial septal defects device closures, patent ductus arteriosus device closures, ventricular septal defect device closures\nExpertise in peripheral interventions especially stenting in aortic dissections, Takayasu arteritis\nSpecial Interests:\nStructural Heart Disease Interventions especially left atrial appendage closure, TAVI, devices in congenital heart disease\nComplex coronary interventions especially chronic total occlusion, left main intervention, rota-ablation\nAcademics - Training fellows in cardiology; Actively involved in publications & research',
#   'doctors.languages_spoken': 'Kannada\nHindi\nEnglish\nTulu\nMalayalam',
#   'doctors.awards_achievements': 'Authored and co-authored more than 50 publications\nPerformed the maximum number of left atrial appendage closures in India\nPrinciple Investigator and Co-investigator in multiple trials – completed and on-going\nAssist Project (EU funded study on Rheumatic Fever and Rheumatic Heart Disease\nSchool Health Study PI (Philips Initiative).\nTuxedo Trial PI (Bostan Scientific Initiative)\nSuperia Trial PI (Superia Initiative).\nNeonatal Heart Disease Screening trial PI (Philips Initiative).\nStoke evaluation - (Xerox Initiative)\nWireless Ultraportable Mobile Technology Based Electrocardiogram System – Co-PI (Intel Initiative)\nManipal BOP– Portable ECHO user requirements and analysis (Philips Initiative).\nUltrasound usability testing (Philips Initiative).\nLeader Trial Co –PI (Novanordis Initiative).\nSCORED Trial PI (Sanofi Initiative)\n\nOrganized and conducted multiple conferences\na. Manipal Cardiology update 1 November 2011 - Organizing Secretary\nb. Manipal Interventional Cardiology conference April 2012 - Organizing secretary\nc. Manipal Cardiology update 2 November 2012 - Organizing Secretary\nd. Manipal Cardiology update 3 November 2013 - Organizing Secretary\n\nYoungest Professor in Cardiology (Professor since 2013)\nAuthored and Co-Authored chapters in books\na. Diabetes and Heart API Textbook 2010 Dr Ranjan Shetty, Dr N R Rau.\nb. Emerging and Re-emerging infection API Textbook 2007 Rita Sood, Ranjan Shetty\nc. Healthy Heart, Manipal University Press\n\nGuide and Co-Guide for many thesis and research\nTraining fellows in Cardiology – DM, DNB\nSmt Kirpaul Kaur Medal – The Best House Physician 2002',
#   'doctors.talks_publications': 'Heart attack <a href="https://bangaloremirror.indiatimes.com/bangalore/others/another-heart-attack/articleshow/77401155.cms" class="click_calls" target="_blank">Click Here</a>\n\nAnother heart attack <a href="https://bangaloremirror.indiatimes.com/bangalore/others/another-heart-attack/articleshow/77401155.cms" class="click_calls" target="_blank">Click Here</a>\n\nCOVID-19 patients in Karnataka given blood thinners to prevent clots, Dr Ranjan Shetty, HoD and consultant, Interventional Cardiology, Manipal Hospitals. Post recovery, patients continue to suffer from COVID-19 sym <a href="https://www.newindianexpress.com/states/karnataka/2020/aug/17/covid-19-patients-in-karnataka-given-blood-thinners-to-prevent-clots-2184390.html" class="click_calls" target="_blank">Click Here</a>\n\nRecovered from Covid? There\'s a new test in town - Dr. Ranjan Shetty, HOD and Interventional Cardiologist, Old Airport Road Manipal Hospitals <a href="https://bangaloremirror.indiatimes.com/bangalore/others/recovered-from-covid-19-theres-a-new-test-in-town/articleshow/77748288.cms " class="click_calls" target="_blank">Click Here</a>\n\nAccording to Dr. Ranjan Shetty, HOD and Interventional Cardiologist at Old Airport Road Manipal Hospitals, ‘COVID doesn’t only affect the lungs but also heart and other organs. He further explains that D Dimer tests help determine if there are any clots. It should also be done for those in home isolation.’ <a href="https://bangaloremirror.indiatimes.com/bangalore/others/recovered-from-covid-19-theres-a-new-test-in-town/articleshow/77748288.cms " class="click_calls" target="_blank">Click Here</a>\n\nDr. Satyanarayana Mysore HOD Pulmonology Department, Manipal Hospitals, Old Airport Road, Dr Ranjan Shetty, an Interventional Cardiologist, Manipal Hospitals, Old Airport Road, Dr. Ranjith Mohan, Consultant, Infectious disease <a href=" https://bangaloremirror.indiatimes.com/bangalore/cover-story/survival-of-the-fittest/articleshow/77793838.cms" class="click_calls" target="_blank">Click Here</a>\n\n',
#   'doctors.meta_title': 'Dr Ranjan Shetty | HOD & Consultant Interventional Cardiologist in Oldairportroad, Bangalore',
#   'doctors.meta_description': 'Dr Ranjan Shetty is a hod & consultant interventional cardiologist in Oldairportroad, Bangalore Works at Manipal Hospitals expertise in coronary interventions. Book Appointment Online',
#   'doctors.meta_keywords': '',
#   'other_meta_tags': '',
#   'display_order': '1',
#   'slug': 'dr-ranjan-shetty-hod-and-consultant-interventional-cardiologist-cardiology',
#   'status_ind': '1',
#   'created_date': '2020-06-04 08:22:42',
#   'last_modified_date': '2020-09-07 10:49:58',
#   'created_by': '1',
#   'last_modified_by': '3',
#   'doc_name': 'Dr. Ranjan Shetty'},
#  {'doctor_id': '5',
#   'DoctorCode': 'MHBDC1850',
#   'DeptCode': 'MHBDCAR',
#   'DeptName': 'CARDIOLOGY MHB',
#   'doctors_codes.designation': 'Consultant - Interventional Cardiology',
#   'title_text': '',
#   'doctors.qualification': 'MBBS | MD (Gen Med); JSS Medical College, Mysore (RGUHS)\nDNB (Cardiology); Wockhardt Hospital, Bengaluru\nObservership in Advanced Heart Failure & Heart Transplant at Royal Papworth Hospital, Cambridge, United Kingdom',
#   'profile': None,
#   'photo': 'https://www.manipalhospitals.com/uploads/doctors_photo/Cardiology_-_Dr_Roopa.png',
#   'content': '',
#   'doctors.fellowship_membership': 'Indian Medical Association.\nLife member of Cardiological Society of India.\nLife member of Indian Academy of Echocardiography.',
#   'doctors.field_expertise': 'Coronary & Peripheral Interventions.\nPerformed around 1000 Coronary Angiogram & 400 Angioplasties annually.\nPart of the Cardiac Transplants Programme\nActively involved in the case of advanced Heart failure & Cardiomyopathy patients both on in outpatients & inpatients basis.\nEmergency Echo along with intra operative echo and TEE, including Paediatric echo\nComplete 2D & Doppler Echocardiography\nAll advance Echocardiographic techniques like 3D Echocardiography\nAssessment of CRT criteria, Strain & Strain rate imaging, Speckle Tracking, Contrast Echocardiography & Dobutamine stress.',
#   'doctors.languages_spoken': 'English\nKannada\nHindi\nTamil\nTelugu',
#   'doctors.awards_achievements': '',
#   'doctors.talks_publications': '',
#   'doctors.meta_title': 'Dr Roopa R | Consultant Interventional Cardiologist in Oldairportroad, Bangalore',
#   'doctors.meta_description': 'Dr Roopa R is a consultant interventional cardiologist in Oldairportroad, Bangalore Works at Manipal Hospitals expertise in coronary & peripheral interventions. Book Appointment Online.',
#   'doctors.meta_keywords': '',
#   'other_meta_tags': '',
#   'display_order': '1',
#   'slug': 'dr-roopa-r-consultant-interventional-cardiology',
#   'status_ind': '1',
#   'created_date': '2019-12-17 21:15:03',
#   'last_modified_date': '2020-06-10 11:14:51',
#   'created_by': '1',
#   'last_modified_by': '3',
#   'doc_name': 'Dr. Roopa R'},
#  {'doctor_id': '641',
#   'DoctorCode': 'MHBDC993',
#   'DeptCode': 'MHBDCAR',
#   'DeptName': 'CARDIOLOGY MHB',
#   'doctors_codes.designation': 'Consultant - Cardiac Electrophysiology, Cardiology',
#   'title_text': '',
#   'doctors.qualification': 'MBBS\nMD (Internal Medicine)\nDM (Cardiology)',
#   'profile': None,
#   'photo': 'https://www.manipalhospitals.com/uploads/doctors_photo/Dr_Sinam.png',
#   'content': '',
#   'doctors.fellowship_membership': 'Cardiac Electrophysiology Fellowship (RGUHS, Bengaluru)\nCardio-oncology Fellowship (Royal Brompton Hospital, London, UK)\nIndian Heart Rhythm Society\nAsia Pacific Heart Rhythm Society\nHeart Rhythm Society\nEuropean Heart Rhythm Association',
#   'doctors.field_expertise': 'Cardiac Arrhythmia Management\nCardioversion\nPacemaker Implantation\nAICD Implantation (Automated Implanter Cardioverter Defibrillator)\nCRT/CRTD Implantation (Cardiac resynchronization therapy)\nRadiofrequency Ablation\nCardio-Oncology',
#   'doctors.languages_spoken': 'English\nHindi\nAssamese\nBengali\nManipuri',
#   'doctors.awards_achievements': '',
#   'doctors.talks_publications': '“A randomized trial of yoga therapy for reflex syncope”. Sinam Inaoton Singha, R.S. Gangwar, B. Banavalikar, D. Padmanabhan, V. Gangwar, S.P. Valappil, M.K. Ghadei, M.Ali, J. Shenthar, abstract at ESC Paris, 2019.\n“Efficacy of ivabradine in the management of focal atrial tachycardia”. Jayaprakash Shenthar, Bharatraj Banavalikar, Deepak Padmanabhan, Javed Parvej, P.V. Sanjai, Sinam Inaoton Singha, abstract published at Journal of American College of Cardiology, Volume 73, Issue 9, Supplement 1, March 2019.\n“Incidence, predictors and gradation of upper extremity venous obstruction after transvenous pacemaker implantation”. Jayaprakash Shenthar, Deepak Padmanabhan, Bharatraj Banavalikar, P.V. Sanjai, Sinam Inaoton Singha, Vivek Tripathi. Article published in Indian Heart Journal, March 2019\n“Clinical and electrophysiological correlates of incessant ivabradine sensitive atrial tachycardia”. Bharatraj Banavalikar, Jayaprakash Shenthar, Deepak Padmanabhan, Sanjai Valappil, Sinam Inaoton Singha, Anju Kottayan, Milan Ghadei, Muzaffar Ali, article accepted for publication in Circulation (Arrhythmia & EP).\n“Spectrum of conduction abnormalities in patients with a VASIS type 2b response during head up tilt test and their clinical outcomes”. S.P. Valappil, D. Padmanabhan, B. Bharatraj, Sinam Inaoton Singha, G. Milan, A. Muzaffar, J. Shenthar, abstract at ESC Paris 2019\n“Trends in pacemaker implantation at a tertiary care referral hospital from South India: a decade in review.” Sinam Inaoton Singha, Deepak Padmanabhan, Bharatraj Banavalikar, Sanjai P V, Sathish S, Muzaffar Ali, Milan Ghadei, Jayaprakash Shenthar, abstract at IHRS annual meet Jaipur, 2018.\n“Safety and efficacy of ibutilide for acute cardioversion of rheumatic atrial fibrillation”. Bharatraj Banavalikar, Deepak Padmanabhan, S P Valappil, Sinam Inaoton Singha, Jayaprakash Shenthar, abstract at APHRS 2018, TAIPEI\n“How to detect and guide the management of cardiac perforation by pacing leads”. Deepak Padmanabhan, Bharatraj Banabalikar, S P Valappil, Sinam Inaoton Singha, Jayaprakash Shenthar, abstract at APHRS 2018, TAIPEI\n“Etiology and clinical outcomes of syncope in patients with structural heart disease and negative electrophysiology study: A prospective study using an insertable loop recorder”. Jayaprakash Shenthar, Deepak Padmanabhan, Bharatraj Banavalikar, Mukund Prabhu, Sinam Inaoton Singha, Sanjai P V. abstract at APHRS 2018, TAIPEI\n“Spectrum of rhythm and conduction abnormalities in patients with cardioinhibitory response during head up tilt test- a single-centre experience”. Jayaprakash Shenthar, Deppak Padmanabhan, Bharatraj Banavalikar, S.P. Valappil, Sinam Inaoton Singha, abstract at IHRS annual meet Jaipur, 2018\n“Usefulness of mitral leaflet separation index in assessing mitral stenosis severity before and after percutaneous transvenous mitral commissurotomy” abstract at 64th Annual CSI Conference and SAARC Cardiac Congress, December 2012, New Delhi. Sinam Inaoton Singha, B Dutta, A K Bhattacharyya, J C Barkataki, P J Bhattacharyya.\nA review article titled “medical management of atrial fibrillation” in Medicine Update, Assam Chapter, API, VOLUME XIV, 2011.',
#   'doctors.meta_title': 'Dr Sinam Inaoton Singha | Consultant Cardiac Electrophysiology in Oldairportroad, Bangalore',
#   'doctors.meta_description': 'Dr Sinam Inaoton Singha is a Consultant Cardiac Electrophysiology at Manipal Hospitals Oldairportroad, Bangalore expertise in Cardiac Arrhythmia Management, Cardioversion, Pacemaker Implantation, AICD Implantation, Radiofrequency Ablatio, Cardio-Oncology.',
#   'doctors.meta_keywords': '',
#   'other_meta_tags': '',
#   'display_order': '1',
#   'slug': 'dr-sinam-inaoton-singha-consultant-cardiac-electrophysiology-cardiology',
#   'status_ind': '1',
#   'created_date': '2019-12-17 21:15:03',
#   'last_modified_date': '2020-07-02 11:23:22',
#   'created_by': '1',
#   'last_modified_by': '3',
#   'doc_name': 'Dr. Sinam Inaoton Singha'},
#  {'doctor_id': '6',
#   'DoctorCode': 'MHBDC1797',
#   'DeptCode': 'MHBDCAR',
#   'DeptName': 'CARDIOLOGY MHB',
#   'doctors_codes.designation': 'Consultant - Interventional Cardiology, Cardiac Electrophysiology',
#   'title_text': '',
#   'doctors.qualification': 'MBBS: Bangalore Medical College, Bangalore\nMD: Maulana Azad Medical College, New Delhi\nDM: Postgraduate Institute of Medical Education and Research (PGIMER), Chandigarh',
#   'profile': None,
#   'photo': 'https://www.manipalhospitals.com/uploads/doctors_photo/Cardiology_-_Dr_Sridhara.png',
#   'content': '',
#   'doctors.fellowship_membership': 'Member of Cardiological Society of India\nMember of Indian Heart Rhythm Society\nMember of Indian Association of Clinical Medicine\nMember of Asia Pacific Heart Rhythm Society',
#   'doctors.field_expertise': 'Has over 14 years’ experience and expertise on all the Cardiac Interventions and Diagnostic procedures performed in Cathlab\nExperienced Interventionist for Coronary and Structural Heart Diseases including Valvular Interventions. Performed large number of Primary Percutaneous emergency lifesaving interventions in Heart Attack.\nSpecial interest in Cardiac Electrophysiology for treatment of Cardiac Arrhythmias. Has vast experience in Cardiac Electronic Device implantations including pacemakers CRT-P and CRT-D.\nExperienced and expertise in performing Electrophysiology Ablation procedures for SVT like AVNRT and Accessory Pathways.\nPerformed Atrial Flutter and Idiopathic VT Ablations with 3D Electro Anatomical mapping systems. Also has gained expertise and experience in Paediatric Catheterization procedures including Device Closure.',
#   'doctors.languages_spoken': 'Kannada\nTelugu\nEnglish\nHindi',
#   'doctors.awards_achievements': 'Rotary Gold Medal for MD- Medicine 2001 from Delhi University\nNova Nordisk Educational Grant Award for Best Research work at National Level for Diabetes \nGold Medal for application of Fuzzy Logic for diagnosing CAD in PHC- Institution of Engineers of India',
#   'doctors.talks_publications': 'Presented MD research work at API conference, NewDelhi-2001\nPresented DM research work at CSI conference- Bangalore-2004\nConducted and Organized many Health Camps in Tumkur and Kolar Districts\nMD Research work in Indian Practitioner Journal 2002\nStroke a rare presentation of Cardiac Amyloidosis- Neurology India March 2003\nDevice closure of ASD, VSD and PDA. Indian Journal of Cardiology 2004\nCyanotic spells in Tetrology of Fallot, Indian Journal of Cardiology 2005\nRadiation Hazards in Cathlab, indian Journal of cardiology 2005',
#   'doctors.meta_title': 'Dr Sridhara G | Consultant Interventional Cardiology  in Oldairportroad, Bangalore',
#   'doctors.meta_description': 'Dr Sridhara G is a Consultant Interventional Cardiology at Manipal Hospitals in Oldairportroad, Bangalore expertise in all the Cardiac Interventions and Diagnostic procedures performed in Cathlab.',
#   'doctors.meta_keywords': '',
#   'other_meta_tags': '',
#   'display_order': '1',
#   'slug': 'dr-sridhara-g-consultant-interventional-cardiology-and-electro-physiology',
#   'status_ind': '1',
#   'created_date': '2019-12-17 21:22:06',
#   'last_modified_date': '2020-07-02 11:26:23',
#   'created_by': '1',
#   'last_modified_by': '3',
#   'doc_name': 'Dr. Sridhara G'},
#  {'doctor_id': '8',
#   'DoctorCode': 'MHBCARD24',
#   'DeptCode': 'MHBDCAR',
#   'DeptName': 'CARDIOLOGY MHB',
#   'doctors_codes.designation': 'Consultant - Cardiology',
#   'title_text': '',
#   'doctors.qualification': 'MBBS - AFMC Pune University\nMD (Medicine) – AFMC Pune University\nDM (Cardiology) - AFMC Pune University\nFRCP (E) (Hon)',
#   'profile': None,
#   'photo': 'https://www.manipalhospitals.com/uploads/doctors_photo/Dr_Iyengar_01.png',
#   'content': '',
#   'doctors.fellowship_membership': 'Life member of Cardiological Society of India\nFellow of Indian College of Cardiology\nMember of European Society of Cardiology.',
#   'doctors.field_expertise': 'Special Interest: Acute coronary syndromes\nHeart Failure\nDyslipidemia',
#   'doctors.languages_spoken': 'English\nKannada\nHindi\nTamil',
#   'doctors.awards_achievements': 'Director General Armed Forces Services Silver Medal\nVishishta Seva Medal (VSM) by The President of India\nPM Naik Memorial Oration Award, Cardiological Society of India, Karnataka Chapter\nPharmacia Oration Award, Indian College of Cardiology\nExaminer in DM (Cardiology) – RGUH Bangalore, Tamil Nadu University, Pune University, Vellore',
#   'doctors.talks_publications': '53 papers in National and International journals',
#   'doctors.meta_title': 'Dr  W G CDR S S Iyengar | Top Cardiologist in Oldairportroad, Bangalore',
#   'doctors.meta_description': 'Dr  W G CDR S S Iyengar is the Top Cardiologist in Oldairportroad, Bangalore works at Manipal Hospitals expertise in acute coronary syndromes, heart failure, and Dyslipidemia.',
#   'doctors.meta_keywords': '',
#   'other_meta_tags': '',
#   'display_order': '1',
#   'slug': 'dr-wg-cdr-s-s-iyengar-consultant-interventional-cardiology',
#   'status_ind': '1',
#   'created_date': '2019-12-16 07:07:21',
#   'last_modified_date': '2020-06-29 10:43:12',
#   'created_by': '1',
#   'last_modified_by': '3',
#   'doc_name': 'Dr. Wg Cdr SS Iyengar'}]

# %%
import requests
import json
from requests.auth import HTTPBasicAuth

search_id = 1

api_response = requests.get('https://test.manipalhospitals.com/chatbot-get-hospitals-speciality/'+str(search_id),auth = HTTPBasicAuth('manipalchatbotapi','manipalchatbotapi'))
speciality_response = json.loads(api_response.text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-3-9870922ffdd0> in <module>
#       6
#       7 api_response = requests.get('https://test.manipalhospitals.com/chatbot-get-hospitals-speciality/'+str(search_id),auth = HTTPBasicAuth('manipalchatbotapi','manipalchatbotapi'))
# ----> 8 speciality_response = json.loads(api_response.text)
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 5 (char 4)

# %%
api_response = requests.get('https://test.manipalhospitals.com/chatbot-get-hospitals-speciality/'+str(1),auth = HTTPBasicAuth('manipalchatbotapi','manipalchatbotapi'))

# %%
api_response
# Out:
# <Response [404]>

# %%
x = {
  "responseId": "c2b1131f-8d73-4142-b2e2-50080157476f-aabf4fdf",
  "queryResult": {
    "queryText": "Old Airport Road",
    "action": "DefaultWelcomeIntent.DefaultWelcomeIntent-custom.english-custom.english-bookappointment-custom.english-bookappointment-male-custom",
    "parameters": {
      "Banguluruhospitals": "1"
    },
    
    "fulfillmentMessages": [
      {
        "platform": "ACTIONS_ON_GOOGLE",
        "simpleResponses": {
          "simpleResponses": [
            {
              "textToSpeech": "Select the specialty you are looking for:"
            }
          ]
        }
      },
      {
        "platform": "ACTIONS_ON_GOOGLE",
        "listSelect": {
          "title": "Centre Of Excellence",
          "items": [
            {
              "info": {
                "key": "Accident and Emergency Care"
              },
              "title": "Accident and Emergency Care",
              "image": {}
            },
            {
              "info": {
                "key": "Cancer Care"
              },
              "title": "Cancer Care",
              "image": {}
            },
            {
              "info": {
                "key": "Cardiology"
              },
              "title": "Cardiology",
              "image": {}
            },
            {
              "info": {
                "key": "Cardiothoracic Vascular Surgery"
              },
              "title": "Cardiothoracic Vascular Surgery",
              "image": {}
            },
            {
              "info": {
                "key": "Gastrointestinal Science"
              },
              "title": "Gastrointestinal Science",
              "image": {}
            },
            {
              "info": {
                "key": "Laparoscopic Surgery"
              },
              "title": "Laparoscopic Surgery",
              "image": {}
            },
            {
              "info": {
                "key": "Liver Transplantation Surgery"
              },
              "title": "Liver Transplantation Surgery",
              "image": {}
            },
            {
              "info": {
                "key": "Nephrology"
              },
              "title": "Nephrology",
              "image": {}
            },
            {
              "info": {
                "key": "Neurology"
              },
              "title": "Neurology",
              "image": {}
            },
            {
              "info": {
                "key": "Neurosurgery"
              },
              "title": "Neurosurgery",
              "image": {}
            },
            {
              "info": {
                "key": "Obstetrics and Gynaecology"
              },
              "title": "Obstetrics and Gynaecology",
              "image": {}
            },
            {
              "info": {
                "key": "Orthopaedics"
              },
              "title": "Orthopaedics",
              "image": {}
            },
            {
              "info": {
                "key": "Paediatric And Child Care"
              },
              "title": "Paediatric And Child Care",
              "image": {}
            },
            {
              "info": {
                "key": "Rheumatology"
              },
              "title": "Rheumatology",
              "image": {}
            },
            {
              "info": {
                "key": "Spine Care"
              },
              "title": "Spine Care",
              "image": {}
            },
            {
              "info": {
                "key": "Urology"
              },
              "title": "Urology",
              "image": {}
            },
            {
              "info": {
                "key": "Anesthesiology"
              },
              "title": "Anesthesiology",
              "image": {}
            },
            {
              "info": {
                "key": "Bariatric Surgery"
              },
              "title": "Bariatric Surgery",
              "image": {}
            },
            {
              "info": {
                "key": "Dental Medicine"
              },
              "title": "Dental Medicine",
              "image": {}
            },
            {
              "info": {
                "key": "Dermatology"
              },
              "title": "Dermatology",
              "image": {}
            },
            {
              "info": {
                "key": "Diabetes and Endocrinology"
              },
              "title": "Diabetes and Endocrinology",
              "image": {}
            },
            {
              "info": {
                "key": "Ear Nose Throat"
              },
              "title": "Ear Nose Throat",
              "image": {}
            },
            {
              "info": {
                "key": "Fetal Medicine"
              },
              "title": "Fetal Medicine",
              "image": {}
            },
            {
              "info": {
                "key": "General Surgery"
              },
              "title": "General Surgery",
              "image": {}
            },
            {
              "info": {
                "key": "General Medicine"
              },
              "title": "General Medicine",
              "image": {}
            },
            {
              "info": {
                "key": "Genetics"
              },
              "title": "Genetics",
              "image": {}
            },
            {
              "info": {
                "key": "Geriatric Medicine"
              },
              "title": "Geriatric Medicine",
              "image": {}
            },
            {
              "info": {
                "key": "Hepatobiliary Surgery"
              },
              "title": "Hepatobiliary Surgery",
              "image": {}
            },
            {
              "info": {
                "key": "ICU and Critical Care"
              },
              "title": "ICU and Critical Care",
              "image": {}
            },
            {
              "info": {
                "key": "Infectious Disease"
              },
              "title": "Infectious Disease",
              "image": {}
            },
            {
              "info": {
                "key": "Internal Medicine"
              },
              "title": "Internal Medicine",
              "image": {}
            },
            {
              "info": {
                "key": "Laboratory Medicine"
              },
              "title": "Laboratory Medicine",
              "image": {}
            },
            {
              "info": {
                "key": "Neonatology & NICU"
              },
              "title": "Neonatology & NICU",
              "image": {}
            },
            {
              "info": {
                "key": "Nuclear Medicine"
              },
              "title": "Nuclear Medicine",
              "image": {}
            },
            {
              "info": {
                "key": "Nutrition And Dietetics"
              },
              "title": "Nutrition And Dietetics",
              "image": {}
            },
            {
              "info": {
                "key": "Ophthalmology"
              },
              "title": "Ophthalmology",
              "image": {}
            },
            {
              "info": {
                "key": "Plastic And Cosmetic Surgery"
              },
              "title": "Plastic And Cosmetic Surgery",
              "image": {}
            },
            {
              "info": {
                "key": "Psychiatry"
              },
              "title": "Psychiatry",
              "image": {}
            },
            {
              "info": {
                "key": "Psychology"
              },
              "title": "Psychology",
              "image": {}
            },
            {
              "info": {
                "key": "Pulmonology (Respiratory and Sleep Medicine)"
              },
              "title": "Pulmonology (Respiratory and Sleep Medicine)",
              "image": {}
            },
            {
              "info": {
                "key": "Radiology"
              },
              "title": "Radiology",
              "image": {}
            },
            {
              "info": {
                "key": "Rehabilitation Medicine"
              },
              "title": "Rehabilitation Medicine",
              "image": {}
            },
            {
              "info": {
                "key": "Sports Medicine"
              },
              "title": "Sports Medicine",
              "image": {}
            },
            {
              "info": {
                "key": "Vascular and Endovascular Surgery"
              },
              "title": "Vascular and Endovascular Surgery",
              "image": {}
            },
            {
              "info": {
                "key": "Transfusion Medicine"
              },
              "title": "Transfusion Medicine",
              "image": {}
            }
          ]
        }
      }
    ],
    "outputContexts": [
      {
        "name": "projects/manipal-chatbot-test-ceks/locations/global/agent/sessions/b49f8e07-f21b-99e5-13d6-2aaefcd36642/contexts/english-bookappointment-male-problem-followup",
        "lifespanCount": 2,
        "parameters": {
          "Banguluruhospitals.original": "Old Airport Road",
          "Banguluruhospitals": "1"
        }
      },
      {
        "name": "projects/manipal-chatbot-test-ceks/locations/global/agent/sessions/b49f8e07-f21b-99e5-13d6-2aaefcd36642/contexts/english-bookappointment-oldairportroad-followup",
        "lifespanCount": 2,
        "parameters": {
          "Banguluruhospitals": "1",
          "Banguluruhospitals.original": "Old Airport Road"
        }
      },
      {
        "name": "projects/manipal-chatbot-test-ceks/locations/global/agent/sessions/b49f8e07-f21b-99e5-13d6-2aaefcd36642/contexts/english-bookappointment-male-followup",
        "lifespanCount": 1,
        "parameters": {
          "Banguluruhospitals.original": "Old Airport Road",
          "Banguluruhospitals": "1"
        }
      }
    ],
    "intent": {
      "name": "projects/manipal-chatbot-test-ceks/agent/intents/78fe470c-6cff-4d51-b0e8-6ef8e650980e",
      "displayName": "english - book appointment - banaguluru"
    },
    "intentDetectionConfidence": 1,
    "diagnosticInfo": {
      "webhook_latency_ms": 366
    },
    "languageCode": "en"
  },
  "webhookStatus": {
    "message": "Webhook execution successful"
  },
  "agentId": "9ed7c9a2-41ee-47da-987b-e6e15f008c04"
}

# %%
x['queryResult']['outputContexts'][0]['parameters']['Banguluruhospitals']
# Out:
# '1'
